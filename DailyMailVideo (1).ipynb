# %% [markdown]
# ### Video URL and description
#
# https://www.tiktok.com/t/ZP8DV6W9R/
# This TikTok video was posted by the DailyMail and describes how Taylor Swift is being urged to sue President Donald Trump after her music was used in a White House Video.
#
# ### Research Question
# Is the general sentiment of Taylor Swift's music getting endorsed by Donald Trump, and are other singers getting added to the conversation?
#
# ### Concepts and a description of how they changed with coding
# concept1 = "Code 1 if comments support Taylor Swift, but Code 0 for everything else."
# concept2 = "Code 1 if comments support Donald Trump, but Code 0 for everything else."
#
# These concepts changed heavily throughout the coding. They become much more specific, defining what specific emojis meant and what constituted a comment as being pro or anti Trump or Swift.
#
# ### Your final LLM prompt and Inter-Rater Reliability scores
# Final prompt:
#
# You are a research assistant.
#                 You will receive a series of tiktok comments,
#                Concept 1 — Support for Taylor Swift
#                Code “1” for Concept 1 if the comment expresses any of the following: Positive support, praise, or defense of Taylor Swift, Positive descriptions of her music, character, or actions, Agreement that she should sue Trump or take legal action, Criticism of Donald Trump, his administration, or MAGA culture in a way that implies support for Swift, Emojis commonly associated with Swift fans or Democratic support (e.g., 💙 blue hearts), Mocking or dismissing Trump with the clear implication that Swift is in the right
#                Code “0” for Concept 1 if: The comment supports Trump or criticizes Swift, The comment is neutral, off-topic, unclear, sarcastic without clear direction, or contains only emojis/text like “fyp,” “lol,” “???”, The comment discusses the situation without taking a side, The comment criticizes BOTH Trump and Swift, The comment criticizes Swift fans without criticizing Trump, The comment is unrelated to the Swift/Trump debate
#                Concept 2 — Support for Donald Trump
#                Code “1” for Concept 2 if the comment expresses any of the following: Support, praise, or defense of Donald Trump, Statements implying Swift is dramatic, overreacting, or “needs to calm down”, Claims that Swift will “have to sue everyone now” or that she is being unreasonable, Criticism of Swift or her fanbase in a way that implies Trump is right, Emojis commonly associated with Trump/MAGA (e.g., ❤️ red hearts), Mocking Swift, her music, or her fans in the context of the dispute
#                Code “0” for Concept 2 if: The comment supports Swift, The comment criticizes Trump, The comment is neutral, unrelated, unclear, sarcastic without explicit stance, or contains only emojis/text like “fyp,” “lol,” random characters, The comment criticizes both Swift and Trump equally, The comment attacks politics or celebrities in general without reference to Trump or Swift
#                Important Clarification Rules: A single comment can receive two zeros.   If a comment is ambiguous, vague, or not clearly supporting either side, code both concepts as 0. Sarcasm must be coded based on explicit, clear wording only—not speculation If sarcasm is not obvious through wording, code 0.
#                Political comments unrelated to the Swift–Trump conflict (e.g., “Biden sucks”) should be coded as 0 for both concepts.
#
# Final inter-rater reliability scores:
# 0.576
# 0.071
#
# ### A brief reflection on how you changed your prompting strategies to achieve better inter-rater reliability scores
#
# We had to change the prompting strategy several time to achieve better scores. We made the concepts way more specifc by providing examples for each type of comment. However, sometimes we would make the prompt more specific, but our rating would be lower.
#
# ### 1-3 charts or graphs that answer your research question

# %% [markdown]
# ![](graph1.png)

# %% [markdown]
# ### A 2-3 paragraph write up reporting your results and answering your research question
#
# Through the analysis we conducted on this TikTok video, support for Taylor Swift appeared more substantial and frequent than explicit support for President Donald Trump. The number of comments coded as supporting Swift was notably higher than those supporting Trump. Many commenters defended Swift, framed Trump’s use of her music as distasteful, or expressed approval of the idea that she should take legal action. In contrast, pro-Trump comments were significantly fewer and tended to cluster around themes such as dismissing Swift’s reaction or framing her fans as overly dramatic. Pro-Trump comments were often more critical of Swift, rather than directly supportive of Trump. Many TikTok users also reacted with jokes, confusion, or off-topic comments.
#
# In terms of the second portion of the research question, users did not shift their attention toward other artists. Most comments maintained focus on Swift, Trump, or the controversy itself rather than drawing comparisons to other musicians. This comes as a suprise since singers like Olivia Rodrigo found themselves in similar situations.
